# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %% [markdown]
# # Structure factor

# %%
#load data
#1 s_k plot per system size, total 3, color each potentials

#667
s_k_adp_667 = pd.read_csv('Data/Liquid_Lib_adp_observables/s_k_adp_667.csv')
kpoints_adp_667 = s_k_adp_667.k
s_adp_667 = s_k_adp_667['S(k)']

s_k_eam_667 = pd.read_csv('Data/Liquid_Lib_eam_observables/s_k_eam_667.csv')
kpoints_eam_667 = s_k_eam_667.k
s_eam_667 = s_k_eam_667['S(k)']

s_k_lj_667 = pd.read_csv('Data/Liquid_Lib_lj_observables/s_k_lj_667.csv')
kpoints_lj_667 = s_k_lj_667.k
s_lj_667 = s_k_lj_667['S(k)']

#1335
s_k_adp_1335 = pd.read_csv('Data/Liquid_Lib_adp_observables/s_k_adp_1335.csv')
kpoints_adp_1335 = s_k_adp_1335.k
s_adp_1335 = s_k_adp_1335['S(k)']

s_k_eam_1335 = pd.read_csv('Data/Liquid_Lib_eam_observables/s_k_eam_1335.csv')
kpoints_eam_1335 = s_k_eam_1335.k
s_eam_1335 = s_k_eam_1335['S(k)']

s_k_lj_1335 = pd.read_csv('Data/Liquid_Lib_lj_observables/s_k_lj_1335.csv')
kpoints_lj_1335 = s_k_lj_1335.k
s_lj_1335 = s_k_lj_1335['S(k)']


#2669
s_k_adp_2669 = pd.read_csv('Data/Liquid_Lib_adp_observables/s_k_adp_2669.csv')
kpoints_adp_2669= s_k_adp_2669.k
s_adp_2669 = s_k_adp_2669['S(k)']

s_k_eam_2669 = pd.read_csv('Data/Liquid_Lib_eam_observables/s_k_eam_2669.csv')
kpoints_eam_2669= s_k_eam_2669.k
s_eam_2669 = s_k_eam_2669['S(k)']

s_k_lj_2669 = pd.read_csv('Data/Liquid_Lib_lj_observables/s_k_lj_2669.csv')
kpoints_lj_2669= s_k_lj_2669.k
s_lj_2669 = s_k_lj_2669['S(k)']

# %%
plt.plot(kpoints_adp_667,s_adp_667,c = 'red',label = 'ADP')
plt.plot(kpoints_eam_667,s_eam_667,c = 'blue', label = 'EAM')
plt.plot(kpoints_lj_667,s_lj_667,c = 'green', label = 'LJ')
plt.xlabel('K')
plt.ylabel('S(k)')
plt.title('Structure Factor, System Size N = 667')
plt.legend()

plt.savefig('Images/structurefactor_667.png',dpi = 300)
plt.show()

# %%
plt.plot(kpoints_adp_1335,s_adp_1335,c = 'red',label = 'ADP')
plt.plot(kpoints_eam_1335,s_eam_1335,c = 'blue', label = 'EAM')
plt.plot(kpoints_lj_1335,s_lj_1335,c = 'green', label = 'LJ')
plt.xlabel('K')
plt.ylabel('S(k)')
plt.title('Structure Factor, System Size N = 1335')
plt.legend()

plt.savefig('Images/structurefactor_1335.png',dpi = 300)
plt.show()

# %%
plt.plot(kpoints_adp_2669,s_adp_2669,c = 'red',label = 'ADP')
plt.plot(kpoints_eam_2669,s_eam_2669,c = 'blue', label = 'EAM')
plt.plot(kpoints_lj_2669,s_lj_2669,c = 'green', label = 'LJ')
plt.xlabel('K')
plt.ylabel('S(k)')
plt.title('Structure Factor, System Size N = 2669')
plt.legend()

plt.savefig('Images/structurefactor_2669.png',dpi = 300)
plt.show()

# %% [markdown]
# # Pair correlation

# %%
g_r = pd.read_csv('Data/g_r.csv')
r = g_r.r
g = g_r['g(r)']

# %%
plt.plot(r,g,c = 'red')
plt.xlabel(r'Distance ($\AA$)')
plt.ylabel('g(r)')
plt.title('Pair Correlation Function')

plt.savefig('Images/paircorr.png',dpi = 300)
plt.show()

# %% [markdown]
# # VV AC Time

# %%
#load data

#667
ac_adp_667 = pd.read_csv('Data/Liquid_Lib_adp_observables/vcc_t_adp_667.csv')
t_adp_667 = ac_adp_667.t
c_adp_667 = np.array(ac_adp_667['C_vv(t)'])
c_adp_667 = c_adp_667/667

ac_eam_667 = pd.read_csv('Data/Liquid_Lib_eam_observables/vcc_t_eam_667.csv')
t_eam_667 = ac_eam_667.t
c_eam_667 = np.array(ac_eam_667['C_vv(t)'])
c_eam_667 = c_eam_667/667

ac_lj_667 = pd.read_csv('Data/Liquid_Lib_lj_observables/vcc_t_lj_667.csv')
t_lj_667 = ac_lj_667.t
c_lj_667 = np.array(ac_lj_667['C_vv(t)'])
c_lj_667 = c_lj_667/667

#1335
ac_adp_1335 = pd.read_csv('Data/Liquid_Lib_adp_observables/vcc_t_adp_1335.csv')
t_adp_1335 = ac_adp_1335.t
c_adp_1335 = np.array(ac_adp_1335['C_vv(t)'])
c_adp_1335 = c_adp_1335/1335

ac_eam_1335 = pd.read_csv('Data/Liquid_Lib_eam_observables/vcc_t_eam_1335.csv')
t_eam_1335 = ac_eam_1335.t
c_eam_1335 = np.array(ac_eam_1335['C_vv(t)'])
c_eam_1335 = c_eam_1335/1335

ac_lj_1335 = pd.read_csv('Data/Liquid_Lib_lj_observables/vcc_t_lj_1335.csv')
t_lj_1335 = ac_lj_1335.t
c_lj_1335 = np.array(ac_lj_1335['C_vv(t)'])
c_lj_1335 = c_lj_1335/1335

#2669
ac_adp_2669 = pd.read_csv('Data/Liquid_Lib_adp_observables/vcc_t_adp_2669.csv')
t_adp_2669 = ac_adp_2669.t
c_adp_2669 = np.array(ac_adp_2669['C_vv(t)'])
c_adp_2669 = c_adp_2669/2669

ac_eam_2669 = pd.read_csv('Data/Liquid_Lib_eam_observables/vcc_t_eam_2669.csv')
t_eam_2669 = ac_eam_2669.t
c_eam_2669 = np.array(ac_eam_2669['C_vv(t)'])
c_eam_2669 = c_eam_2669/2669

ac_lj_2669 = pd.read_csv('Data/Liquid_Lib_lj_observables/vcc_t_lj_2669.csv')
t_lj_2669 = ac_lj_2669.t
c_lj_2669 = np.array(ac_lj_2669['C_vv(t)'])
c_lj_2669 = c_lj_2669/2669

# %%
plt.plot(t_adp_667,c_adp_667,c = 'red',label = 'ADP')
plt.plot(t_eam_667,c_eam_667,c = 'blue', label = 'EAM')
plt.plot(t_lj_667,c_lj_667,c = 'green', label = 'LJ')
plt.xlabel('Time (ps)')
plt.ylabel('Correlation')
plt.title('Velocity-Velocity Autocorrelation Time, System Size N = 667')
plt.legend()

plt.savefig('Images/vv_actime_667.png',dpi = 300)
plt.show()

# %%
plt.plot(t_adp_1335,c_adp_1335,c = 'red',label = 'ADP')
plt.plot(t_eam_1335,c_eam_1335,c = 'blue', label = 'EAM')
plt.plot(t_lj_1335,c_lj_1335,c = 'green', label = 'LJ')
plt.xlabel('Time (ps)')
plt.ylabel('Corrleation')
plt.title('Velocity-Velocity Autocorrelation Time, System Size N = 1335')
plt.legend()

plt.savefig('Images/vv_actime_1335.png',dpi = 300)
plt.show()

# %%
plt.plot(t_adp_2669,c_adp_2669,c = 'red',label = 'ADP')
plt.plot(t_eam_2669,c_eam_2669,c = 'blue', label = 'EAM')
plt.plot(t_lj_2669,c_lj_2669,c = 'green', label = 'LJ')
plt.xlabel('Time (ps)')
plt.ylabel('Correlation')
plt.title('Velocity-Velocity Autocorrelation Time, System Size N = 2669')
plt.legend()

plt.savefig('Images/vv_actime_2669.png',dpi = 300)
plt.show()

# %%
plt.plot(t,C,c = 'red')
plt.xlabel('Time (ps)')
plt.ylabel('Correlation')
plt.title('Velocity-Velocity Autocorrelation Time')
plt.xlim(0,0.02)

plt.savefig('Images/vv_actime.png',dpi = 300)
plt.show()

# %% [markdown]
# # Diffusion Coefficient

# %%
#load data

#667
msd_adp_667 = pd.read_csv('Data/Liquid_Lib_adp_observables/r2_t_adp_667.csv')
t_adp_667 = msd_adp_667.t
r2_adp_667 = msd_adp_667['<r2(t)>']

msd_eam_667 = pd.read_csv('Data/Liquid_Lib_eam_observables/r2_t_eam_667.csv')
t_eam_667 = msd_eam_667.t
r2_eam_667 = msd_eam_667['<r2(t)>']

msd_lj_667 = pd.read_csv('Data/Liquid_Lib_lj_observables/r2_t_lj_667.csv')
t_lj_667 = msd_lj_667.t
r2_lj_667 = msd_lj_667['<r2(t)>']

#1335
msd_adp_1335 = pd.read_csv('Data/Liquid_Lib_adp_observables/r2_t_adp_1335.csv')
t_adp_1335 = msd_adp_1335.t
r2_adp_1335 = msd_adp_1335['<r2(t)>']

msd_eam_1335 = pd.read_csv('Data/Liquid_Lib_eam_observables/r2_t_eam_1335.csv')
t_eam_1335 = msd_eam_1335.t
r2_eam_1335 = msd_eam_1335['<r2(t)>']

msd_lj_1335 = pd.read_csv('Data/Liquid_Lib_lj_observables/r2_t_lj_1335.csv')
t_lj_1335 = msd_lj_1335.t
r2_lj_1335 = msd_lj_1335['<r2(t)>']


#2669
msd_adp_2669 = pd.read_csv('Data/Liquid_Lib_adp_observables/r2_t_adp_2669.csv')
t_adp_2669 = msd_adp_2669.t
r2_adp_2669 = msd_adp_2669['<r2(t)>']

msd_eam_2669 = pd.read_csv('Data/Liquid_Lib_eam_observables/r2_t_eam_2669.csv')
t_eam_2669 = msd_eam_2669.t
r2_eam_2669 = msd_eam_2669['<r2(t)>']

msd_lj_2669 = pd.read_csv('Data/Liquid_Lib_lj_observables/r2_t_lj_2669.csv')
t_lj_2669 = msd_lj_2669.t
r2_lj_2669 = msd_lj_2669['<r2(t)>']

# %%
meansq_dist = pd.read_csv('Data/r2_t.csv')
t = meansq_dist.t
r2 = meansq_dist['r2(t)']

# %%
plt.plot(t_adp_667,r2_adp_667,c = 'red',label = 'ADP')
plt.plot(t_eam_667,r2_eam_667,c = 'blue', label = 'EAM')
plt.plot(t_lj_667,r2_lj_667,c = 'green', label = 'LJ')
plt.xlabel('Time (ps)')
plt.ylabel('Mean Squared Displacement')
plt.title('Evaluation of Diffusion Coefficient, System Size N = 667')
plt.legend()

#plt.savefig('Images/r2_667.png',dpi = 300)
plt.show()

# %%
#diffusion constant check
linregress(t_lj_2669, r2_lj_2669)
# Out:
# LinregressResult(slope=0.2749146847232529, intercept=0.05880437194422556, rvalue=0.27595702086033064, pvalue=0.09828064904134433, stderr=0.16185371228702322, intercept_stderr=0.0033873473819916156)

# %%
plt.plot(t_adp_1335,r2_adp_1335,c = 'red',label = 'ADP')
plt.plot(t_eam_1335,r2_eam_1335,c = 'blue', label = 'EAM')
plt.plot(t_lj_1335,r2_lj_1335,c = 'green', label = 'LJ')
plt.xlabel('Time (ps)')
plt.ylabel('Mean Squared Displacement')
plt.title('Evaluation of Diffusion Coefficient, System Size N = 1335')
plt.legend()

plt.savefig('Images/r2_1335.png',dpi = 300)
plt.show()

# %%
plt.plot(t_adp_2669,r2_adp_2669,c = 'red',label = 'ADP')
plt.plot(t_eam_2669,r2_eam_2669,c = 'blue', label = 'EAM')
plt.plot(t_lj_2669,r2_lj_2669,c = 'green', label = 'LJ')
plt.xlabel('Time (ps)')
plt.ylabel('Mean Squared Displacement')
plt.title('Evaluation of Diffusion Coefficient, System Size N = 2669')
plt.legend()

plt.savefig('Images/r2_2669.png',dpi = 300)
plt.show()

# %%
plt.plot(t,r2,c = 'red')
plt.xlabel('Time (ps)')
plt.ylabel('Mean Squared Displacement')
plt.title('Evaluation of Diffusion Coefficient')
plt.savefig('Images/diff.png',dpi = 300)
plt.show()
linregress(t, r2)
# Out:
# LinregressResult(slope=97.58878607259591, intercept=0.1280327202614835, rvalue=0.9999641602651795, pvalue=8.152120296099201e-66, stderr=0.14839802959291526, intercept_stderr=0.03312425423151819)

# %% [markdown]
# # Specific Heat

# %%
#load data

#667
log_adp_667 = pd.read_csv('Data/adp/667/log_667.csv')
step_adp_667 = log_adp_667.Step.dropna()
H_adp_667 = log_adp_667.Enthalpy

log_eam_667 = pd.read_csv('Data/EAM/667/log_667.csv')
step_eam_667 = log_eam_667.Step
H_eam_667 = log_eam_667.Enthalpy

log_lj_667 = pd.read_csv('Data/lj/667/log_667.csv')
step_lj_667 = log_lj_667.Step
H_lj_667 = log_lj_667.Enthalpy

#1335
log_adp_1335 = pd.read_csv('Data/adp/1335/log_1335.csv')
step_adp_1335 = log_adp_1335.Step
H_adp_1335 = log_adp_1335.Enthalpy

log_eam_1335 = pd.read_csv('Data/EAM/1335/log_1335.csv')
step_eam_1335 = log_eam_1335.Step
H_eam_1335 = log_eam_1335.Enthalpy

log_lj_1335 = pd.read_csv('Data/lj/1335/log_1335.csv')
step_lj_1335 = log_lj_1335.Step
H_lj_1335 = log_lj_1335.Enthalpy

#2669
log_adp_2669 = pd.read_csv('Data/adp/2669/log_2669.csv')
step_adp_2669 = log_adp_2669.Step
H_adp_2669 = log_adp_2669.Enthalpy

log_eam_2669 = pd.read_csv('Data/EAM/2669/log_2669.csv')
step_eam_2669 = log_eam_2669.Step
H_eam_2669 = log_eam_2669.Enthalpy

log_lj_2669 = pd.read_csv('Data/lj/2669/log_2669.csv')
step_lj_2669 = log_lj_2669.Step
H_lj_2669 = log_lj_2669.Enthalpy

# %%
plt.plot(step_adp_667,H_adp_667,c = 'red',label = 'ADP')
plt.plot(step_eam_667,H_eam_667,c = 'blue', label = 'EAM')
plt.plot(step_lj_667,H_lj_667,c = 'green', label = 'LJ')
plt.xlabel('Steps')
plt.ylabel('Enthalpy')
plt.title('Evaluation of Specific Heat, System Size N = 667')
plt.legend()

plt.savefig('Images/Cv_667.png',dpi = 300)
plt.show()

# %%
plt.plot(step_adp_1335,H_adp_1335,c = 'red',label = 'ADP')
plt.plot(step_eam_1335,H_eam_1335,c = 'blue', label = 'EAM')
plt.plot(step_lj_1335,H_lj_1335,c = 'green', label = 'LJ')
plt.xlabel('Steps')
plt.ylabel('Enthalpy')
plt.title('Evaluation of Specific Heat, System Size N = 1335')
plt.legend()

plt.savefig('Images/Cv_1335.png',dpi = 300)
plt.show()

# %%
plt.plot(step_adp_2669,H_adp_2669,c = 'red',label = 'ADP')
plt.plot(step_eam_2669,H_eam_2669,c = 'blue', label = 'EAM')
plt.plot(step_lj_2669,H_lj_2669,c = 'green', label = 'LJ')
plt.xlabel('Steps')
plt.ylabel('Enthalpy')
plt.title('Evaluation of Specific Heat, System Size N = 2669')
plt.legend()

plt.savefig('Images/Cv_2669.png',dpi = 300)
plt.show()

# %%
print(np.var(H_lj_2669))
# Out:
# 96442.14738176818
